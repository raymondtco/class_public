# %%
import numpy as np
# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt

import pylab

# %%
inter = np.genfromtxt("/global/homes/b/bhorowit/class_public/output/ncdmb_explanatory05_cl.dat")#"./output/explanatory23_cl.dat")
noint = np.genfromtxt("/global/homes/b/bhorowit/class_public/output/ncdmb_explanatory12_cl.dat")#"./output/explanatory23_cl.dat")
sint = np.genfromtxt("/global/homes/b/bhorowit/class_public/output/ncdmb_explanatory11_cl.dat")#"./output/explanatory23_cl.dat")

#inter_rec = np.genfromtxt("/global/homes/b/bhorowit/ncdm_explanatory14_cl.dat")#"./output/explanatory23_cl.dat")

# %%
cl_inter = np.array([inter[i,0]**1*(inter[i,0]+1)*j/(2*np.pi) for i,j in enumerate(inter[:,1])])
cl_noint = np.array([noint[i,0]**1*(noint[i,0]+1)*j/(2*np.pi) for i,j in enumerate(noint[:,1])])
cl_int_rec = np.array([sint[i,0]**1*(sint[i,0]+1)*j/(2*np.pi) for i,j in enumerate(sint[:,1])])


pylab.plot(inter[:,0],cl_inter,label = "No Interaction, lmax = 15")
##pylab.plot(sint[:,0],cl_int_rec,label = r"with integral ($a^4 G^m = 1 \times 10^{-26}$), lmax = 20")
pylab.plot(noint[:,0],cl_noint,label = r"with integral ($a^4 G^m = 1 \times 10^{-26}$), lmax = 15")
#pylab.loglog(one_int[:,0],cl_one_int,label = "Planck + $N_{\text{eff}}=1.0$ + int")
#pylab.loglog(one_noint[:,0],cl_one_noint,label = "Planck + $(N_{\t{eff}}=1.0)$")


plt.rc('font', family='serif')
pylab.legend(loc=4)
plt.xlim((0,2150))
plt.ylim((0,0.5*10**-4))
pylab.grid()
pylab.xlabel("$l$")
pylab.ylabel("$l(l+1)C_l/2\pi$")# in $[\mu k]^2$")
pylab.rcParams['figure.figsize'] = (10.0, 8.0)

# %%
sint
# Out:
# array([[  2.00000000e+00,   7.40096776e+11,   9.39209052e+02, ...,
#           6.70009911e+08,  -7.13740795e+08,   1.87742415e+04],
#        [  3.00000000e+00,   5.91143175e+09,   8.87671805e+00, ...,
#           2.81507809e+09,  -5.50225903e+06,   8.12855013e+01],
#        [  4.00000000e+00,   1.15791411e+08,   1.83311682e+00, ...,
#           2.59805390e+09,  -1.04207631e+05,   5.85915459e+00],
#        ...,
#        [  2.99800000e+03,   7.71776778e+01,   1.64891096e-06, ...,
#           1.85969785e+04,   3.00364830e-02,   3.99289262e-10],
#        [  2.99900000e+03,   7.89668413e+01,   1.63793655e-06, ...,
#           1.72285828e+04,   3.06991572e-02,   4.09427168e-10],
#        [  3.00000000e+03,   8.07757065e+01,   1.62703348e-06, ...,
#           1.58374111e+04,   3.13825286e-02,   4.19689731e-10]])

# %%
\=

















\










]]
